# %%
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("THUDM/chatglm2-6b", trust_remote_code=True)
model = AutoModel.from_pretrained("THUDM/chatglm2-6b", trust_remote_code=True)
model = model.half().cuda()
model = model.eval()
# Out:
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:3                                                                                    │
# │                                                                                                  │
# │   1 from transformers import AutoTokenizer, AutoModel                                            │
# │   2 tokenizer = AutoTokenizer.from_pretrained("THUDM/chatglm2-6b", trust_remote_code=True)       │
# │ ❱ 3 model = AutoModel.from_pretrained("THUDM/chatglm2-6b", trust_remote_code=True).int8().cu     │
# │   4 model = model.eval()                                                                         │
# │   5                                                                                              │
# │   6                                                                                              │
# │                                                                                                  │
# │ /home/zhangfuwen/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1614 in       │
# │ __getattr__                                                                                      │
# │                                                                                                  │
# │   1611 │   │   │   modules = self.__dict__['_modules']                                           │
# │   1612 │   │   │   if name in modules:                                                           │
# │   1613 │   │   │   │   return modules[name]                                                      │
# │ ❱ 1614 │   │   raise AttributeError("'{}' object has no attribute '{}'".format(                  │
# │   1615 │   │   │   type(self).__name__, name))                                                   │
# │   1616 │                                                                                         │
# │   1617 │   def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:             │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# AttributeError: 'ChatGLMForConditionalGeneration' object has no attribute 'int8'

# %%
history = []
while True:
    prompt=input()
    response, history = model.chat(tokenizer, "你好", history=history)
    print(response)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:4                                                                                    │
# │                                                                                                  │
# │   1 history = []                                                                                 │
# │   2 while True:                                                                                  │
# │   3 │   prompt=input()                                                                           │
# │ ❱ 4 │   response, history = model.chat(tokenizer, "你好", history=history)                       │
# │   5 │   print(response)                                                                          │
# │   6                                                                                              │
# │                                                                                                  │
# │ /home/zhangfuwen/anaconda3/lib/python3.10/site-packages/torch/utils/_contextlib.py:115 in        │
# │ decorate_context                                                                                 │
# │                                                                                                  │
# │   112 │   @functools.wraps(func)                                                                 │
# │   113 │   def decorate_context(*args, **kwargs):                                                 │
# │   114 │   │   with ctx_factory():                                                                │
# │ ❱ 115 │   │   │   return func(*args, **kwargs)                                                   │
# │   116 │                                                                                          │
# │   117 │   return decorate_context                                                                │
# │   118                                                                                            │
# │                                                                                                  │
# │ /home/zhangfuwen/.cache/huggingface/modules/transformers_modules/THUDM/chatglm2-6b/e186c891cf643 │
# │ 10ac66ef10a87e6635fa6c2a579/modeling_chatglm.py:948 in chat                                      │
# │                                                                                                  │
# │    945 │   │   gen_kwargs = {"max_length": max_length, "num_beams": num_beams, "do_sample": do_  │
# │    946 │   │   │   │   │     "temperature": temperature, "logits_processor": logits_processor,   │
# │    947 │   │   inputs = self.build_inputs(tokenizer, query, history=history)                     │
# │ ❱  948 │   │   outputs = self.generate(**inputs, **gen_kwargs)                                   │
# │    949 │   │   outputs = outputs.tolist()[0][len(inputs["input_ids"][0]):]                       │
# │    950 │   │   response = tokenizer.decode(outputs)                                              │
# │    951 │   │   response = self.process_response(response)                                        │
# │                                                                                                  │
# │ /home/zhangfuwen/anaconda3/lib/python3.10/site-packages/torch/utils/_contextlib.py:115 in        │
# │ decorate_context                                                                                 │
# │                                                                                                  │
# │   112 │   @functools.wraps(func)                                                                 │
# │   113 │   def decorate_context(*args, **kwargs):                                                 │
# │   114 │   │   with ctx_factory():                                                                │
# │ ❱ 115 │   │   │   return func(*args, **kwargs)                                                   │
# │   116 │                                                                                          │
# │   117 │   return decorate_context                                                                │
# │   118                                                                                            │
# │                                                                                                  │
# │ /home/zhangfuwen/anaconda3/lib/python3.10/site-packages/transformers/generation/utils.py:1568 in │
# │ generate                                                                                         │
# │                                                                                                  │
# │   1565 │   │   │   )                                                                             │
# │   1566 │   │   │                                                                                 │
# │   1567 │   │   │   # 13. run sample                                                              │
# │ ❱ 1568 │   │   │   return self.sample(                                                           │
# │   1569 │   │   │   │   input_ids,                                                                │
# │   1570 │   │   │   │   logits_processor=logits_processor,                                        │
# │   1571 │   │   │   │   logits_warper=logits_warper,                                              │
# │                                                                                                  │
# │ /home/zhangfuwen/anaconda3/lib/python3.10/site-packages/transformers/generation/utils.py:2615 in │
# │ sample                                                                                           │
# │                                                                                                  │
# │   2612 │   │   │   model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)  │
# │   2613 │   │   │                                                                                 │
# │   2614 │   │   │   # forward pass to get next token                                              │
# │ ❱ 2615 │   │   │   outputs = self(                                                               │
# │   2616 │   │   │   │   **model_inputs,                                                           │
# │   2617 │   │   │   │   return_dict=True,                                                         │
# │   2618 │   │   │   │   output_attentions=output_attentions,                                      │
# │                                                                                                  │
# │ /home/zhangfuwen/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1501 in       │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ /home/zhangfuwen/.cache/huggingface/modules/transformers_modules/THUDM/chatglm2-6b/e186c891cf643 │
# │ 10ac66ef10a87e6635fa6c2a579/modeling_chatglm.py:848 in forward                                   │
# │                                                                                                  │
# │    845 │   │   use_cache = use_cache if use_cache is not None else self.config.use_cache         │
# │    846 │   │   return_dict = return_dict if return_dict is not None else self.config.use_return  │
# │    847 │   │                                                                                     │
# │ ❱  848 │   │   transformer_outputs = self.transformer(                                           │
# │    849 │   │   │   input_ids=input_ids,                                                          │
# │    850 │   │   │   position_ids=position_ids,                                                    │
# │    851 │   │   │   attention_mask=attention_mask,                                                │
# │                                                                                                  │
# │ /home/zhangfuwen/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1501 in       │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ /home/zhangfuwen/.cache/huggingface/modules/transformers_modules/THUDM/chatglm2-6b/e186c891cf643 │
# │ 10ac66ef10a87e6635fa6c2a579/modeling_chatglm.py:744 in forward                                   │
# │                                                                                                  │
# │    741 │   │   rotary_pos_emb = rotary_pos_emb.transpose(0, 1).contiguous()                      │
# │    742 │   │                                                                                     │
# │    743 │   │   # Run encoder.                                                                    │
# │ ❱  744 │   │   hidden_states, presents, all_hidden_states, all_self_attentions = self.encoder(   │
# │    745 │   │   │   inputs_embeds, full_attention_mask, rotary_pos_emb=rotary_pos_emb,            │
# │    746 │   │   │   kv_caches=past_key_values, use_cache=use_cache, output_hidden_states=output_  │
# │    747 │   │   )                                                                                 │
# │                                                                                                  │
# │ /home/zhangfuwen/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1501 in       │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ /home/zhangfuwen/.cache/huggingface/modules/transformers_modules/THUDM/chatglm2-6b/e186c891cf643 │
# │ 10ac66ef10a87e6635fa6c2a579/modeling_chatglm.py:588 in forward                                   │
# │                                                                                                  │
# │    585 │   │   │                                                                                 │
# │    586 │   │   │   layer = self._get_layer(index)                                                │
# │    587 │   │   │                                                                                 │
# │ ❱  588 │   │   │   hidden_states, kv_cache = layer(                                              │
# │    589 │   │   │   │   hidden_states,                                                            │
# │    590 │   │   │   │   attention_mask,                                                           │
# │    591 │   │   │   │   rotary_pos_emb,                                                           │
# │                                                                                                  │
# │ /home/zhangfuwen/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1501 in       │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ /home/zhangfuwen/.cache/huggingface/modules/transformers_modules/THUDM/chatglm2-6b/e186c891cf643 │
# │ 10ac66ef10a87e6635fa6c2a579/modeling_chatglm.py:510 in forward                                   │
# │                                                                                                  │
# │    507 │   │   # Layer norm at the beginning of the transformer layer.                           │
# │    508 │   │   layernorm_output = self.input_layernorm(hidden_states)                            │
# │    509 │   │   # Self attention.                                                                 │
# │ ❱  510 │   │   attention_output, kv_cache = self.self_attention(                                 │
# │    511 │   │   │   layernorm_output,                                                             │
# │    512 │   │   │   attention_mask,                                                               │
# │    513 │   │   │   rotary_pos_emb,                                                               │
# │                                                                                                  │
# │ /home/zhangfuwen/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1501 in       │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ /home/zhangfuwen/.cache/huggingface/modules/transformers_modules/THUDM/chatglm2-6b/e186c891cf643 │
# │ 10ac66ef10a87e6635fa6c2a579/modeling_chatglm.py:342 in forward                                   │
# │                                                                                                  │
# │    339 │   │   # =====================                                                           │
# │    340 │   │                                                                                     │
# │    341 │   │   # Attention heads [sq, b, h] --> [sq, b, (np * 3 * hn)]                           │
# │ ❱  342 │   │   mixed_x_layer = self.query_key_value(hidden_states)                               │
# │    343 │   │                                                                                     │
# │    344 │   │   if self.multi_query_attention:                                                    │
# │    345 │   │   │   (query_layer, key_layer, value_layer) = mixed_x_layer.split(                  │
# │                                                                                                  │
# │ /home/zhangfuwen/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1501 in       │
# │ _call_impl                                                                                       │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ /home/zhangfuwen/anaconda3/lib/python3.10/site-packages/torch/nn/modules/linear.py:114 in        │
# │ forward                                                                                          │
# │                                                                                                  │
# │   111 │   │   │   init.uniform_(self.bias, -bound, bound)                                        │
# │   112 │                                                                                          │
# │   113 │   def forward(self, input: Tensor) -> Tensor:                                            │
# │ ❱ 114 │   │   return F.linear(input, self.weight, self.bias)                                     │
# │   115 │                                                                                          │
# │   116 │   def extra_repr(self) -> str:                                                           │
# │   117 │   │   return 'in_features={}, out_features={}, bias={}'.format(                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# RuntimeError: "addmm_impl_cpu_" not implemented for 'Half'
